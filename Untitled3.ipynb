# %% [markdown]
# <a href="https://colab.research.google.com/github/studentrampal/rampal-demo/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
a = [10,20,30,40]
b = ['engish','maths','hindi','science']
plt.pie(a,labels = b)
plt.show()
